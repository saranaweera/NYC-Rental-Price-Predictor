# %% [markdown]
# Import libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import pickle

# %% [markdown]
# Scrape NYC Neighborhood Mappings from NY State Health Department website. This might be slightly different from neighborhoods used by realtors

# %%
url = 'https://www.health.ny.gov/statistics/cancer/registry/appendix/neighborhoods.htm'

df = pd.read_html(url)[0]

df = df.loc[1:]

df['shift'] = False
df.loc[df.iloc[:,2].isnull(), 'shift'] = True

df.loc[df.loc[:,'shift'], 2] = df.loc[df.loc[:,'shift'],1]
df.loc[df.loc[:,'shift'], 1] = df.loc[df.loc[:,'shift'],0]
df.loc[df['shift'] == True, 0 ] = None

df = df.iloc[:,0:3]

df.columns = ['borough', 'neighborhood', 'zips']

df.borough = df.borough.fillna(method='ffill')
df.head()
# Out:
#   borough                neighborhood                        zips
# 1   Bronx               Central Bronx         10453, 10457, 10460
# 2   Bronx      Bronx Park and Fordham         10458, 10467, 10468
# 3   Bronx  High Bridge and Morrisania         10451, 10452, 10456
# 4   Bronx  Hunts Point and Mott Haven  10454, 10455, 10459, 10474
# 5   Bronx   Kingsbridge and Riverdale                10463, 10471

# %% [markdown]
# Process dataframe to get it into format: Borough, Neighborhood, ZipCode

# %%
df.zips = df.zips.str.split(',')

tempZipDF = pd.concat([pd.DataFrame({'zipCode':v}, index=np.repeat(k,len(v))) 
            for k,v in df.zips.to_dict().items()])   
tempZipDF

neighborhoodsDF = df

neighborhoodsDF = (
    neighborhoodsDF.merge(tempZipDF, left_index=True, right_index=True)
    .loc[:,['borough', 'neighborhood', 'zipCode']]
)

neighborhoodsDF.zipCode = neighborhoodsDF.zipCode.str.strip()

print(neighborhoodsDF.head())
print(neighborhoodsDF.tail())
# Out:
#   borough            neighborhood zipCode
# 1   Bronx           Central Bronx   10453
# 1   Bronx           Central Bronx   10457
# 1   Bronx           Central Bronx   10460
# 2   Bronx  Bronx Park and Fordham   10458
# 2   Bronx  Bronx Park and Fordham   10467
#           borough              neighborhood zipCode
# 40  Staten Island               South Shore   10312
# 41  Staten Island  Stapleton and St. George   10301
# 41  Staten Island  Stapleton and St. George   10304
# 41  Staten Island  Stapleton and St. George   10305
# 42  Staten Island                Mid-Island   10314

# %% [markdown]
# Derive links for zip code landing pages

# %%
url = 'https://hotpads.com/%s/apartments-for-rent' % ('1')

neighborhoodsDF['zipUrlLink'] = neighborhoodsDF.zipCode.apply(lambda x: 'https://hotpads.com/%s/apartments-for-rent' % x)

# %% [markdown]
# Scrape zip code landing page to figure out the number of results pages

# %%
def getNumberOfListings(url):
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    noOfListings = int(soup.find(class_ ='AreaPage-listings-count').text.split()[5])
    return(noOfListings)

# %%
def getSummaryUrlList(url,noOfListings):
    urlList = [
           url if i==0 
           else url+'?start='+ str(i) 
             for i in list(range(0,noOfListings+1,20))
          ]
    return(urlList)

# %%
def getSummaryPageLinks(baseZipUrl):
    noOfListings = getNumberOfListings(baseZipUrl)  
    summaryPageLinks = getSummaryUrlList(baseZipUrl, noOfListings)
    df = pd.DataFrame({'baseZipUrl':np.repeat(baseZipUrl,len(summaryPageLinks)), 'summaryPageLink':summaryPageLinks})
    return(df)

# %%
getSummaryPageLinks('https://hotpads.com/11102/apartments-for-rent').head()
# Out:
#                                      summaryPageLink  \
# 0      https://hotpads.com/11102/apartments-for-rent
# 1  https://hotpads.com/11102/apartments-for-rent?...
# 2  https://hotpads.com/11102/apartments-for-rent?...
# 3  https://hotpads.com/11102/apartments-for-rent?...
# 4  https://hotpads.com/11102/apartments-for-rent?...
#
#                                          zipCode
# 0  https://hotpads.com/11102/apartments-for-rent
# 1  https://hotpads.com/11102/apartments-for-rent
# 2  https://hotpads.com/11102/apartments-for-rent
# 3  https://hotpads.com/11102/apartments-for-rent
# 4  https://hotpads.com/11102/apartments-for-rent

# %%
def getAllSummaryPageLinks(neighborhoodsDF):
    linksDF = None
    for baseZipUrlLink in neighborhoodsDF.zipUrlLink:
        tempDF = None
        
        try:
            print(baseZipUrlLink)
            tempDF = getSummaryPageLinks(baseZipUrlLink)
        except:
            print('Failed !!!!:' + baseZipUrlLink)
        
        if not(tempDF is None):
            if linksDF is None:
                linksDF = tempDF
            else:
                linksDF = pd.concat([linksDF, tempDF])
            # adding delay so that I don't get banned from the website
        time.sleep(2)
    return(linksDF)

# %%
allLinksDF = getAllSummaryPageLinks(neighborhoodsDF)
# Out:
# https://hotpads.com/10453/apartments-for-rent
# https://hotpads.com/10457/apartments-for-rent
# https://hotpads.com/10460/apartments-for-rent
# https://hotpads.com/10458/apartments-for-rent
# https://hotpads.com/10467/apartments-for-rent
# https://hotpads.com/10468/apartments-for-rent
# https://hotpads.com/10451/apartments-for-rent
# https://hotpads.com/10452/apartments-for-rent
# https://hotpads.com/10456/apartments-for-rent
# https://hotpads.com/10454/apartments-for-rent
# https://hotpads.com/10455/apartments-for-rent
# https://hotpads.com/10459/apartments-for-rent
# https://hotpads.com/10474/apartments-for-rent
# https://hotpads.com/10463/apartments-for-rent
# https://hotpads.com/10471/apartments-for-rent
# https://hotpads.com/10466/apartments-for-rent
# https://hotpads.com/10469/apartments-for-rent
# https://hotpads.com/10470/apartments-for-rent
# https://hotpads.com/10475/apartments-for-rent
# https://hotpads.com/10461/apartments-for-rent
# https://hotpads.com/10462/apartments-for-rent
# https://hotpads.com/10464/apartments-for-rent
# https://hotpads.com/10465/apartments-for-rent
# https://hotpads.com/10472/apartments-for-rent
# https://hotpads.com/10473/apartments-for-rent
# https://hotpads.com/11212/apartments-for-rent
# https://hotpads.com/11213/apartments-for-rent
# https://hotpads.com/11216/apartments-for-rent
# https://hotpads.com/11233/apartments-for-rent
# https://hotpads.com/11238/apartments-for-rent
# https://hotpads.com/11209/apartments-for-rent
# https://hotpads.com/11214/apartments-for-rent
# https://hotpads.com/11228/apartments-for-rent
# https://hotpads.com/11204/apartments-for-rent
# https://hotpads.com/11218/apartments-for-rent
# https://hotpads.com/11219/apartments-for-rent
# https://hotpads.com/11230/apartments-for-rent
# https://hotpads.com/11234/apartments-for-rent
# https://hotpads.com/11236/apartments-for-rent
# 2   https://hotpads.com/10301/apartments-for-rent
# 3   https://hotpads.com/10301/apartments-for-rent
# 0   https://hotpads.com/10304/apartments-for-rent
# 1   https://hotpads.com/10304/apartments-for-rent
# 0   https://hotpads.com/10305/apartments-for-rent
# 1   https://hotpads.com/10305/apartments-for-rent
# 2   https://hotpads.com/10305/apartments-for-rent
# 0   https://hotpads.com/10314/apartments-for-rent
# 1   https://hotpads.com/10314/apartments-for-rent
# 2   https://hotpads.com/10314/apartments-for-rent
# 3   https://hotpads.com/10314/apartments-for-rent
#
# [1119 rows x 2 columns]

# %% [markdown]
# Pickle away allLinks data frame

# %%
allLinksDF.to_picke('allLinksDF.pkl')

# %% [markdown]
# There are nearly 30,000 listing on this website. In order to deal with failures, separate summary links to batches.

# %%
t = pd.read_pickle('allLinksDF.pkl')
t = t.rename(columns={'zipCode':'baseZipUrl'})

# %%
t['ordNum'] = range(0,len(t))

# %%
t['batchGroup'] = t.ordNum // 5
t['scrapingStatus'] = 'NotStarted'

# %%
t.to_pickle('allSummaryLinksDF.pkl')

# %%
t = pd.read_pickle('allSummaryLinksDF.pkl')

# %%
neighborhoodSummaryLinkAllDF = neighborhoodsDF.merge(t, left_on='zipUrlLink', right_on='baseZipUrl')
neighborhoodSummaryLinkAllDF.to_pickle('data/neighborhoodSummaryLinkAllDF.pkl')

# %%
for n, g in t.groupby('batchGroup'):
    fileName = 'summaryLinks_'+ str(n) + '.pkl'
    g.to_pickle('data/'+fileName)

# %%
#neighborhoodSummaryLinkAllDF.groupby(['zipCode','ordNum']).size().hist()
for zipcode,dat in neighborhoodSummaryLinkAllDF.groupby('zipCode'):
    filename = 'data/summaryLinksDF_{}.pkl'.format(zipcode)
    dat.to_pickle(filename)

# %%
neighborhoodSummaryLinkAllDF['ordNum'] = neighborhoodSummaryLinkAllDF.groupby('zipCode').zipCode.transform(lambda x: range(0,len(x)))

# %%
neighborhoodSummaryLinkAllDF['batchGroup'] = neighborhoodSummaryLinkAllDF['ordNum']//5

# %%
del neighborhoodSummaryLinkAllDF['baseZipUrl']

# %%
for n,g in neighborhoodSummaryLinkAllDF.groupby(['zipCode','batchGroup']):
    filename = 'data/summaryLinksDF_{}_{}.pkl'.format(n[0],n[1])
    g.to_pickle(filename)

# %%
pd.read_pickle('data/summaryLinksDF_11106_0.pkl').head()
# Out:
#     borough      neighborhood zipCode  \
# 957  Queens  Northwest Queens   11106
# 958  Queens  Northwest Queens   11106
# 959  Queens  Northwest Queens   11106
# 960  Queens  Northwest Queens   11106
# 961  Queens  Northwest Queens   11106
#
#                                         zipUrlLink  \
# 957  https://hotpads.com/11106/apartments-for-rent
# 958  https://hotpads.com/11106/apartments-for-rent
# 959  https://hotpads.com/11106/apartments-for-rent
# 960  https://hotpads.com/11106/apartments-for-rent
# 961  https://hotpads.com/11106/apartments-for-rent
#
#                                        summaryPageLink ordNum batchGroup  \
# 957      https://hotpads.com/11106/apartments-for-rent      0          0
# 958  https://hotpads.com/11106/apartments-for-rent?...      1          0
# 959  https://hotpads.com/11106/apartments-for-rent?...      2          0
# 960  https://hotpads.com/11106/apartments-for-rent?...      3          0
# 961  https://hotpads.com/11106/apartments-for-rent?...      4          0
#
#     scrapingStatus
# 957     NotStarted
# 958     NotStarted
# 959     NotStarted
# 960     NotStarted
# 961     NotStarted

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# type `which chromedriver` from shell to find chromedriver
#chromedriver = "/Volumes/Files/homebrew/bin/chromedriver"
chromedriver = "/usr/local/bin/chromedriver"
driver = webdriver.Chrome(chromedriver)

# %%
driver.get('https://hotpads.com/11102/apartments-for-rent')
#
driver.close()

# %%
#driver.find_elements_by_xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "name", " " ))')
#driver.find_elements_by_xpath("//div[@class='listing-info']/div/a")[0]

def getListingSummaries(url):
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    result =[{'name':c.find_all(class_='name')[0].text, 
          'link':c.find_all(class_ ='Linker Linker-default')[0]['href'],
          'city':c.find_all(class_ ='city')[0].text,
          'min_price':c.find_all(class_ ='min-price')[0].text,
          'no_bedrooms':c.find_all(class_ ='beds')[0].text,
         }  for c in soup.find_all(class_='listing-info')
        ]
    return(result)

# %%
def getAllListingSummariesInForSumPkl(sumPkl):
    listingSummariesAllPagesInZip =[]
    for i in range(0,len(sumPkl)):
        try:
            summaryPageLink = sumPkl.iloc[i].summaryPageLink
            print('Accessing summary page: '+ summaryPageLink)
            listingSummaries = getListingSummaries(summaryPageLink)
            listingSummariesAllPagesInZip.extend(listingSummaries)
        except:
            print('Error getListingSummaries: ' + summaryPageLink)
        #print(listingSummaries)
        time.sleep(1)
    return(listingSummariesAllPagesInZip)

# %% [markdown]
# Go through each summary listings page and get individual listing links and high level information about the listing

# %%
#getListingSummaries('https://hotpads.com/11102/apartments-for-rent')
import shutil
import os


import glob
import time

count = 1
allSummaryLinkPkls = glob.glob("data/summaryLinksDF_*.pkl")

for sumPklFile in allSummaryLinkPkls:
    sumPkl = pd.read_pickle(sumPklFile)
    print('Going through summary pages in '+ sumPklFile)
    summaryListingFn = sumPklFile.replace('data/','data/summaryListings/').replace('summaryLinksDF_','summary')
    summaryListings = getAllListingSummariesInForSumPkl(sumPkl)
    summaryListingsDf = pd.DataFrame(summaryListings)

    print('Pickling: '+ summaryListingFn)
    summaryListingsDf.to_pickle(summaryListingFn)
    
    shutil.move(sumPklFile, "data/done/" + sumPklFile.replace('data/',''))
    print('')
    print(str(count) +' out of ' + str(len(allSummaryLinkPkls)) + ' Done.')
    print('')
    count += 1
# Out:
# Going through summary pages in data/summaryLinksDF_10001_0.pkl
# Accessing summary page: https://hotpads.com/10001/apartments-for-rent
# Accessing summary page: https://hotpads.com/10001/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10001/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10001/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10001/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10001_0.pkl
#
# 1 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10002_0.pkl
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10002_0.pkl
#
# 2 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10002_1.pkl
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10002_1.pkl
#
# 3 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10002_2.pkl
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10002/apartments-for-rent?start=240
# Pickling: data/summaryListings/summary10002_2.pkl
#
# 4 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10003_0.pkl
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10003_0.pkl
#
# 5 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10003_1.pkl
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10003_1.pkl
#
# 6 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10003_2.pkl
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10003_2.pkl
#
# 7 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10003_3.pkl
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=300
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=320
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=340
# Accessing summary page: https://hotpads.com/10003/apartments-for-rent?start=360
# Pickling: data/summaryListings/summary10003_3.pkl
#
# 8 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10004_0.pkl
# Accessing summary page: https://hotpads.com/10004/apartments-for-rent
# Pickling: data/summaryListings/summary10004_0.pkl
#
# 9 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10005_0.pkl
# Accessing summary page: https://hotpads.com/10005/apartments-for-rent
# Pickling: data/summaryListings/summary10005_0.pkl
#
# 10 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10006_0.pkl
# Accessing summary page: https://hotpads.com/10006/apartments-for-rent
# Pickling: data/summaryListings/summary10006_0.pkl
#
# 11 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10007_0.pkl
# Accessing summary page: https://hotpads.com/10007/apartments-for-rent
# Accessing summary page: https://hotpads.com/10007/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary10007_0.pkl
#
# 12 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10009_0.pkl
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10009_0.pkl
#
# 13 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10009_1.pkl
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10009_1.pkl
#
# 14 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10009_2.pkl
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10009/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10009_2.pkl
#
# 15 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10010_0.pkl
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10010_0.pkl
#
# 16 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10010_1.pkl
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10010/apartments-for-rent?start=120
# Pickling: data/summaryListings/summary10010_1.pkl
#
# 17 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10011_0.pkl
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10011_0.pkl
#
# 18 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10011_1.pkl
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10011_1.pkl
#
# 19 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10011_2.pkl
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10011_2.pkl
#
# 20 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10011_3.pkl
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=300
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=320
# Accessing summary page: https://hotpads.com/10011/apartments-for-rent?start=340
# Pickling: data/summaryListings/summary10011_3.pkl
#
# 21 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10012_0.pkl
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10012_0.pkl
#
# 22 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10012_1.pkl
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10012_1.pkl
#
# 23 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10012_2.pkl
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10012/apartments-for-rent?start=240
# Pickling: data/summaryListings/summary10012_2.pkl
#
# 24 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10013_0.pkl
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10013_0.pkl
#
# 25 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10013_1.pkl
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10013_1.pkl
#
# 26 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10013_2.pkl
# Accessing summary page: https://hotpads.com/10013/apartments-for-rent?start=200
# Pickling: data/summaryListings/summary10013_2.pkl
#
# 27 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10014_0.pkl
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10014_0.pkl
#
# 28 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10014_1.pkl
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10014_1.pkl
#
# 29 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10014_2.pkl
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10014/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10014_2.pkl
#
# 30 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10016_0.pkl
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10016_0.pkl
#
# 31 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10016_1.pkl
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10016_1.pkl
#
# 32 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10016_2.pkl
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10016_2.pkl
#
# 33 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10016_3.pkl
# Accessing summary page: https://hotpads.com/10016/apartments-for-rent?start=300
# Pickling: data/summaryListings/summary10016_3.pkl
#
# 34 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10017_0.pkl
# Accessing summary page: https://hotpads.com/10017/apartments-for-rent
# Accessing summary page: https://hotpads.com/10017/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10017/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10017/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10017/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10017_0.pkl
#
# 35 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10018_0.pkl
# Accessing summary page: https://hotpads.com/10018/apartments-for-rent
# Accessing summary page: https://hotpads.com/10018/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10018/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10018_0.pkl
#
# 36 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10019_0.pkl
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10019_0.pkl
#
# 37 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10019_1.pkl
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10019_1.pkl
#
# 38 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10019_2.pkl
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10019/apartments-for-rent?start=260
# Pickling: data/summaryListings/summary10019_2.pkl
#
# 39 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10021_0.pkl
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10021_0.pkl
#
# 40 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10021_1.pkl
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10021_1.pkl
#
# 41 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10021_2.pkl
# Accessing summary page: https://hotpads.com/10021/apartments-for-rent?start=200
# Pickling: data/summaryListings/summary10021_2.pkl
#
# 42 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10022_0.pkl
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10022_0.pkl
#
# 43 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10022_1.pkl
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10022_1.pkl
#
# 44 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10022_2.pkl
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10022/apartments-for-rent?start=220
# Pickling: data/summaryListings/summary10022_2.pkl
#
# 45 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10023_0.pkl
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10023_0.pkl
#
# 46 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10023_1.pkl
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10023_1.pkl
#
# 47 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10023_2.pkl
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10023/apartments-for-rent?start=260
# Pickling: data/summaryListings/summary10023_2.pkl
#
# 48 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10024_0.pkl
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10024_0.pkl
#
# 49 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10024_1.pkl
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10024_1.pkl
#
# 50 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10024_2.pkl
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10024_2.pkl
#
# 51 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10024_3.pkl
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=300
# Accessing summary page: https://hotpads.com/10024/apartments-for-rent?start=320
# Pickling: data/summaryListings/summary10024_3.pkl
#
# 52 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10025_0.pkl
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10025_0.pkl
#
# 53 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10025_1.pkl
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10025_1.pkl
#
# 54 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10025_2.pkl
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10025_2.pkl
#
# 55 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10025_3.pkl
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=300
# Accessing summary page: https://hotpads.com/10025/apartments-for-rent?start=320
# Pickling: data/summaryListings/summary10025_3.pkl
#
# 56 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10026_0.pkl
# Accessing summary page: https://hotpads.com/10026/apartments-for-rent
# Accessing summary page: https://hotpads.com/10026/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10026/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10026/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10026/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10026_0.pkl
#
# 57 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10026_1.pkl
# Accessing summary page: https://hotpads.com/10026/apartments-for-rent?start=100
# Pickling: data/summaryListings/summary10026_1.pkl
#
# 58 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10027_0.pkl
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10027_0.pkl
#
# 59 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10027_1.pkl
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10027/apartments-for-rent?start=140
# Pickling: data/summaryListings/summary10027_1.pkl
#
# 60 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10028_0.pkl
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10028_0.pkl
#
# 61 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10028_1.pkl
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10028_1.pkl
#
# 62 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10028_2.pkl
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10028/apartments-for-rent?start=240
# Pickling: data/summaryListings/summary10028_2.pkl
#
# 63 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10029_0.pkl
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10029_0.pkl
#
# 64 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10029_1.pkl
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10029/apartments-for-rent?start=120
# Pickling: data/summaryListings/summary10029_1.pkl
#
# 65 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10030_0.pkl
# Accessing summary page: https://hotpads.com/10030/apartments-for-rent
# Accessing summary page: https://hotpads.com/10030/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10030/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10030/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10030/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10030_0.pkl
#
# 66 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10030_1.pkl
# Accessing summary page: https://hotpads.com/10030/apartments-for-rent?start=100
# Pickling: data/summaryListings/summary10030_1.pkl
#
# 67 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10031_0.pkl
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10031_0.pkl
#
# 68 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10031_1.pkl
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10031/apartments-for-rent?start=160
# Pickling: data/summaryListings/summary10031_1.pkl
#
# 69 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10032_0.pkl
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10032_0.pkl
#
# 70 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10032_1.pkl
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10032/apartments-for-rent?start=120
# Pickling: data/summaryListings/summary10032_1.pkl
#
# 71 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10033_0.pkl
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10033_0.pkl
#
# 72 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10033_1.pkl
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10033/apartments-for-rent?start=120
# Pickling: data/summaryListings/summary10033_1.pkl
#
# 73 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10034_0.pkl
# Accessing summary page: https://hotpads.com/10034/apartments-for-rent
# Accessing summary page: https://hotpads.com/10034/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10034/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10034/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10034/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10034_0.pkl
#
# 74 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10035_0.pkl
# Accessing summary page: https://hotpads.com/10035/apartments-for-rent
# Accessing summary page: https://hotpads.com/10035/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10035/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10035/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10035/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10035_0.pkl
#
# 75 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10036_0.pkl
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10036_0.pkl
#
# 76 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10036_1.pkl
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10036/apartments-for-rent?start=120
# Pickling: data/summaryListings/summary10036_1.pkl
#
# 77 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10037_0.pkl
# Accessing summary page: https://hotpads.com/10037/apartments-for-rent
# Accessing summary page: https://hotpads.com/10037/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10037/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10037_0.pkl
#
# 78 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10038_0.pkl
# Accessing summary page: https://hotpads.com/10038/apartments-for-rent
# Accessing summary page: https://hotpads.com/10038/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10038/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10038_0.pkl
#
# 79 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10039_0.pkl
# Accessing summary page: https://hotpads.com/10039/apartments-for-rent
# Accessing summary page: https://hotpads.com/10039/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary10039_0.pkl
#
# 80 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10040_0.pkl
# Accessing summary page: https://hotpads.com/10040/apartments-for-rent
# Accessing summary page: https://hotpads.com/10040/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10040/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10040/apartments-for-rent?start=60
# Pickling: data/summaryListings/summary10040_0.pkl
#
# 81 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10044_0.pkl
# Accessing summary page: https://hotpads.com/10044/apartments-for-rent
# Pickling: data/summaryListings/summary10044_0.pkl
#
# 82 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10065_0.pkl
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10065_0.pkl
#
# 83 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10065_1.pkl
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10065/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10065_1.pkl
#
# 84 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10075_0.pkl
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10075_0.pkl
#
# 85 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10075_1.pkl
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10075/apartments-for-rent?start=160
# Pickling: data/summaryListings/summary10075_1.pkl
#
# 86 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10128_0.pkl
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10128_0.pkl
#
# 87 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10128_1.pkl
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10128_1.pkl
#
# 88 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10128_2.pkl
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/10128/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary10128_2.pkl
#
# 89 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10280_0.pkl
# Accessing summary page: https://hotpads.com/10280/apartments-for-rent
# Pickling: data/summaryListings/summary10280_0.pkl
#
# 90 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10301_0.pkl
# Accessing summary page: https://hotpads.com/10301/apartments-for-rent
# Accessing summary page: https://hotpads.com/10301/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10301/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10301/apartments-for-rent?start=60
# Pickling: data/summaryListings/summary10301_0.pkl
#
# 91 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10302_0.pkl
# Accessing summary page: https://hotpads.com/10302/apartments-for-rent
# Pickling: data/summaryListings/summary10302_0.pkl
#
# 92 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10303_0.pkl
# Accessing summary page: https://hotpads.com/10303/apartments-for-rent
# Pickling: data/summaryListings/summary10303_0.pkl
#
# 93 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10304_0.pkl
# Accessing summary page: https://hotpads.com/10304/apartments-for-rent
# Accessing summary page: https://hotpads.com/10304/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary10304_0.pkl
#
# 94 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10305_0.pkl
# Accessing summary page: https://hotpads.com/10305/apartments-for-rent
# Accessing summary page: https://hotpads.com/10305/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10305/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10305_0.pkl
#
# 95 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10306_0.pkl
# Accessing summary page: https://hotpads.com/10306/apartments-for-rent
# Accessing summary page: https://hotpads.com/10306/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10306/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10306_0.pkl
#
# 96 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10307_0.pkl
# Accessing summary page: https://hotpads.com/10307/apartments-for-rent
# Pickling: data/summaryListings/summary10307_0.pkl
#
# 97 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10308_0.pkl
# Accessing summary page: https://hotpads.com/10308/apartments-for-rent
# Accessing summary page: https://hotpads.com/10308/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary10308_0.pkl
#
# 98 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10309_0.pkl
# Accessing summary page: https://hotpads.com/10309/apartments-for-rent
# Accessing summary page: https://hotpads.com/10309/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10309/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10309_0.pkl
#
# 99 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10310_0.pkl
# Accessing summary page: https://hotpads.com/10310/apartments-for-rent
# Accessing summary page: https://hotpads.com/10310/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary10310_0.pkl
#
# 100 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10312_0.pkl
# Accessing summary page: https://hotpads.com/10312/apartments-for-rent
# Accessing summary page: https://hotpads.com/10312/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10312/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary10312_0.pkl
#
# 101 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10314_0.pkl
# Accessing summary page: https://hotpads.com/10314/apartments-for-rent
# Accessing summary page: https://hotpads.com/10314/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10314/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10314/apartments-for-rent?start=60
# Pickling: data/summaryListings/summary10314_0.pkl
#
# 102 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10451_0.pkl
# Accessing summary page: https://hotpads.com/10451/apartments-for-rent
# Pickling: data/summaryListings/summary10451_0.pkl
#
# 103 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10452_0.pkl
# Accessing summary page: https://hotpads.com/10452/apartments-for-rent
# Accessing summary page: https://hotpads.com/10452/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10452/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10452/apartments-for-rent?start=60
# Pickling: data/summaryListings/summary10452_0.pkl
#
# 104 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10453_0.pkl
# Accessing summary page: https://hotpads.com/10453/apartments-for-rent
# Accessing summary page: https://hotpads.com/10453/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10453/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10453/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10453/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10453_0.pkl
#
# 105 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10454_0.pkl
# Accessing summary page: https://hotpads.com/10454/apartments-for-rent
# Pickling: data/summaryListings/summary10454_0.pkl
#
# 106 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10455_0.pkl
# Accessing summary page: https://hotpads.com/10455/apartments-for-rent
# Accessing summary page: https://hotpads.com/10455/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary10455_0.pkl
#
# 107 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10456_0.pkl
# Accessing summary page: https://hotpads.com/10456/apartments-for-rent
# Accessing summary page: https://hotpads.com/10456/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10456/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10456/apartments-for-rent?start=60
# Pickling: data/summaryListings/summary10456_0.pkl
#
# 108 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10457_0.pkl
# Accessing summary page: https://hotpads.com/10457/apartments-for-rent
# Accessing summary page: https://hotpads.com/10457/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10457/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10457/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10457/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10457_0.pkl
#
# 109 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10458_0.pkl
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary10458_0.pkl
#
# 110 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10458_1.pkl
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary10458_1.pkl
#
# 111 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10458_2.pkl
# Accessing summary page: https://hotpads.com/10458/apartments-for-rent?start=200
# Pickling: data/summaryListings/summary10458_2.pkl
#
# 112 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_10459_0.pkl
# ...
#
# 259 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11373_0.pkl
# Accessing summary page: https://hotpads.com/11373/apartments-for-rent
# Accessing summary page: https://hotpads.com/11373/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11373/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary11373_0.pkl
#
# 260 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11374_0.pkl
# Accessing summary page: https://hotpads.com/11374/apartments-for-rent
# Accessing summary page: https://hotpads.com/11374/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11374/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11374/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11374/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11374_0.pkl
#
# 261 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11375_0.pkl
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11375_0.pkl
#
# 262 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11375_1.pkl
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/11375/apartments-for-rent?start=160
# Pickling: data/summaryListings/summary11375_1.pkl
#
# 263 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11377_0.pkl
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11377_0.pkl
#
# 264 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11377_1.pkl
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/11377/apartments-for-rent?start=120
# Pickling: data/summaryListings/summary11377_1.pkl
#
# 265 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11378_0.pkl
# Accessing summary page: https://hotpads.com/11378/apartments-for-rent
# Accessing summary page: https://hotpads.com/11378/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11378/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11378/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11378/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11378_0.pkl
#
# 266 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11378_1.pkl
# Accessing summary page: https://hotpads.com/11378/apartments-for-rent?start=100
# Pickling: data/summaryListings/summary11378_1.pkl
#
# 267 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11379_0.pkl
# Accessing summary page: https://hotpads.com/11379/apartments-for-rent
# Accessing summary page: https://hotpads.com/11379/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11379/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11379/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11379/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11379_0.pkl
#
# 268 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11379_1.pkl
# Accessing summary page: https://hotpads.com/11379/apartments-for-rent?start=100
# Pickling: data/summaryListings/summary11379_1.pkl
#
# 269 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_0.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11385_0.pkl
#
# 270 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_1.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=160
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=180
# Pickling: data/summaryListings/summary11385_1.pkl
#
# 271 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_2.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=200
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=220
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=240
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=260
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=280
# Pickling: data/summaryListings/summary11385_2.pkl
#
# 272 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_3.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=300
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=320
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=340
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=360
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=380
# Pickling: data/summaryListings/summary11385_3.pkl
#
# 273 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_4.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=400
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=420
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=440
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=460
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=480
# Pickling: data/summaryListings/summary11385_4.pkl
#
# 274 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_5.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=500
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=520
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=540
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=560
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=580
# Pickling: data/summaryListings/summary11385_5.pkl
#
# 275 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11385_6.pkl
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=600
# Accessing summary page: https://hotpads.com/11385/apartments-for-rent?start=620
# Pickling: data/summaryListings/summary11385_6.pkl
#
# 276 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11411_0.pkl
# Accessing summary page: https://hotpads.com/11411/apartments-for-rent
# Pickling: data/summaryListings/summary11411_0.pkl
#
# 277 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11412_0.pkl
# Accessing summary page: https://hotpads.com/11412/apartments-for-rent
# Accessing summary page: https://hotpads.com/11412/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11412_0.pkl
#
# 278 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11413_0.pkl
# Accessing summary page: https://hotpads.com/11413/apartments-for-rent
# Pickling: data/summaryListings/summary11413_0.pkl
#
# 279 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11414_0.pkl
# Accessing summary page: https://hotpads.com/11414/apartments-for-rent
# Accessing summary page: https://hotpads.com/11414/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11414_0.pkl
#
# 280 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11415_0.pkl
# Accessing summary page: https://hotpads.com/11415/apartments-for-rent
# Accessing summary page: https://hotpads.com/11415/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11415/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary11415_0.pkl
#
# 281 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11416_0.pkl
# Accessing summary page: https://hotpads.com/11416/apartments-for-rent
# Accessing summary page: https://hotpads.com/11416/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11416_0.pkl
#
# 282 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11417_0.pkl
# Accessing summary page: https://hotpads.com/11417/apartments-for-rent
# Accessing summary page: https://hotpads.com/11417/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11417_0.pkl
#
# 283 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11418_0.pkl
# Accessing summary page: https://hotpads.com/11418/apartments-for-rent
# Accessing summary page: https://hotpads.com/11418/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11418/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary11418_0.pkl
#
# 284 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11419_0.pkl
# Accessing summary page: https://hotpads.com/11419/apartments-for-rent
# Accessing summary page: https://hotpads.com/11419/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11419_0.pkl
#
# 285 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11420_0.pkl
# Accessing summary page: https://hotpads.com/11420/apartments-for-rent
# Accessing summary page: https://hotpads.com/11420/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11420_0.pkl
#
# 286 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11421_0.pkl
# Accessing summary page: https://hotpads.com/11421/apartments-for-rent
# Accessing summary page: https://hotpads.com/11421/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11421/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11421/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11421/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11421_0.pkl
#
# 287 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11422_0.pkl
# Accessing summary page: https://hotpads.com/11422/apartments-for-rent
# Pickling: data/summaryListings/summary11422_0.pkl
#
# 288 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11423_0.pkl
# Accessing summary page: https://hotpads.com/11423/apartments-for-rent
# Accessing summary page: https://hotpads.com/11423/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11423_0.pkl
#
# 289 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11426_0.pkl
# Accessing summary page: https://hotpads.com/11426/apartments-for-rent
# Accessing summary page: https://hotpads.com/11426/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11426_0.pkl
#
# 290 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11427_0.pkl
# Accessing summary page: https://hotpads.com/11427/apartments-for-rent
# Pickling: data/summaryListings/summary11427_0.pkl
#
# 291 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11428_0.pkl
# Accessing summary page: https://hotpads.com/11428/apartments-for-rent
# Pickling: data/summaryListings/summary11428_0.pkl
#
# 292 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11429_0.pkl
# Accessing summary page: https://hotpads.com/11429/apartments-for-rent
# Accessing summary page: https://hotpads.com/11429/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11429_0.pkl
#
# 293 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11432_0.pkl
# Accessing summary page: https://hotpads.com/11432/apartments-for-rent
# Accessing summary page: https://hotpads.com/11432/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11432/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11432/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11432/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11432_0.pkl
#
# 294 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11432_1.pkl
# Accessing summary page: https://hotpads.com/11432/apartments-for-rent?start=100
# Pickling: data/summaryListings/summary11432_1.pkl
#
# 295 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11433_0.pkl
# Accessing summary page: https://hotpads.com/11433/apartments-for-rent
# Pickling: data/summaryListings/summary11433_0.pkl
#
# 296 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11434_0.pkl
# Accessing summary page: https://hotpads.com/11434/apartments-for-rent
# Pickling: data/summaryListings/summary11434_0.pkl
#
# 297 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11435_0.pkl
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=40
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=60
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=80
# Pickling: data/summaryListings/summary11435_0.pkl
#
# 298 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11435_1.pkl
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=100
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=120
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=140
# Accessing summary page: https://hotpads.com/11435/apartments-for-rent?start=160
# Pickling: data/summaryListings/summary11435_1.pkl
#
# 299 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11436_0.pkl
# Accessing summary page: https://hotpads.com/11436/apartments-for-rent
# Pickling: data/summaryListings/summary11436_0.pkl
#
# 300 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11691_0.pkl
# Accessing summary page: https://hotpads.com/11691/apartments-for-rent
# Accessing summary page: https://hotpads.com/11691/apartments-for-rent?start=20
# Accessing summary page: https://hotpads.com/11691/apartments-for-rent?start=40
# Pickling: data/summaryListings/summary11691_0.pkl
#
# 301 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11692_0.pkl
# Accessing summary page: https://hotpads.com/11692/apartments-for-rent
# Accessing summary page: https://hotpads.com/11692/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11692_0.pkl
#
# 302 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11693_0.pkl
# Accessing summary page: https://hotpads.com/11693/apartments-for-rent
# Pickling: data/summaryListings/summary11693_0.pkl
#
# 303 out of 304 Done.
#
# Going through summary pages in data/summaryLinksDF_11694_0.pkl
# Accessing summary page: https://hotpads.com/11694/apartments-for-rent
# Accessing summary page: https://hotpads.com/11694/apartments-for-rent?start=20
# Pickling: data/summaryListings/summary11694_0.pkl
#
# 304 out of 304 Done.

# 78  /4744-vernon-blvd-long-island-city-ny-11101-tu...    $2,475
# 79  /3422-42nd-st-long-island-city-ny-11101-sns042...    $1,750
# 80  /37-11-30thave-long-island-city-ny-11101-1sqkr...    $2,000
# 81  /1115-45th-ave-long-island-city-ny-11101-sp8ex...    $2,000
# 82  /4830-37th-st-long-island-city-ny-11101-smxesf...    $1,650
# 83  /3416-41st-st-long-island-city-ny-11101-tuwhak...    $1,800
# 84  /3402-steinway-st-long-island-city-ny-11101-1j...    $1,850
#
#                       name       no_bedrooms
# 0               27 On 27th       1 to 2 beds
# 1           4441 Purves St  Studio to 2 beds
# 2           29-28 41st Ave            Studio
# 3         3427 43rd St #2R            2 beds
# 4             4237 27th St             1 bed
# 5             475 48th Ave  Studio to 3 beds
# 6    42-60 Crescent St #7C            2 beds
# 7           519 Borden Ave       1 to 2 beds
# 8          3451 41st St #1            2 beds
# 9       42-17 27th St #17E             1 bed
# 10         3734 29th St #5            Studio
# 11        3827 28th St #2F            3 beds
# 12      3925 29th St #FOUR            3 beds
# 13        3733 28th St #11             1 bed
# 14         4550 Pearson St  Studio to 2 beds
# 15        2614 Jackson Ave  Studio to 2 beds
# 16        4728 11th St #3A             1 bed
# 17           1158 49th Ave             1 bed
# 18          4325 Hunter St       1 to 2 beds
# 19     44-72 11th St #A206             1 bed
# 20        226 50th Ave #9A            2 beds
# 21         4550 Pearson St  Studio to 2 beds
# 22        2614 Jackson Ave  Studio to 2 beds
# 23         3430 44th St #2            2 beds
# 24         3925 24th St #5            2 beds
# 25            4142 24th St       1 to 3 beds
# 26        4728 11th St #3A             1 bed
# 27       3134 47th Ave #2A            2 beds
# 28           1158 49th Ave             1 bed
# 29        4134 Crescent St            Studio
# ..                     ...               ...
# 55       2310 41st Ave #7E            Studio
# 56           3204 38th Ave  Studio to 1 beds
# 57        3616 38th St #12             1 bed
# 58     4415 Purves St #10D            Studio
# 59         3434 44th St #2             1 bed
# 60       25-19 39th Ave #1            7 beds
# 61         3434 44th St #2             1 bed
# 62        34-34 44th St #2            2 beds
# 63        4850 38th St #6B             1 bed
# 64         4029 23rd St #4            2 beds
# 65       4004 36th Ave #4D             1 bed
# 66         2139 45th Rd #A            2 beds
# 67  4215 Crescent St #202B            Studio
# 68         3422 44th St #1             1 bed
# 69        40-4 36th Ave #4            2 beds
# 70        3946 29th St #3H            2 beds
# 71           2310 45th Ave       2 to 3 beds
# 72           41-21 24th St            Studio
# 73    3428 Steinway St #6A             1 bed
# 74       3447 42nd St #3RR            Studio
# 75     4819 Vernon Blvd #3             1 bed
# 76        1115 46th Rd #4G            2 beds
# 77        39-46 27th St #2            2 beds
# 78    4744 Vernon Blvd #4R             1 bed
# 79       3422 42nd St #1RL             1 bed
# 80       37-11 30THAVE #10            2 beds
# 81       1115 45th Ave #2H             1 bed
# 82        4830 37th St #3B            Studio
# 83        3416 41st St #4C             1 bed
# 84     3402 Steinway St #1             1 bed
#
# [85 rows x 5 columns]
