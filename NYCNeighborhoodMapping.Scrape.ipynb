# %% [markdown]
# Import libraries

# %%
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Scrape NYC Neighborhood mapping from NY State Health website. These are not quite the mappings a realtor would use. But should be good enough

# %%
url = 'https://www.health.ny.gov/statistics/cancer/registry/appendix/neighborhoods.htm'

df = pd.read_html(url)[0]

# %% [markdown]
# Do preprocessing to get it in a format that I can use

# %%
df = df.loc[1:]

df['shift'] = False
df.loc[df.iloc[:,2].isnull(), 'shift'] = True

df.loc[df.loc[:,'shift'], 2] = df.loc[df.loc[:,'shift'],1]
df.loc[df.loc[:,'shift'], 1] = df.loc[df.loc[:,'shift'],0]
df.loc[df['shift'] == True, 0 ] = None

df = df.iloc[:,0:3]

df.columns = ['Borough', 'Neighborhood', 'Zips']

df.Borough = df.Borough.fillna(method='ffill')
df.head()
# Out:
#   Borough                Neighborhood                        Zips
# 1   Bronx               Central Bronx         10453, 10457, 10460
# 2   Bronx      Bronx Park and Fordham         10458, 10467, 10468
# 3   Bronx  High Bridge and Morrisania         10451, 10452, 10456
# 4   Bronx  Hunts Point and Mott Haven  10454, 10455, 10459, 10474
# 5   Bronx   Kingsbridge and Riverdale                10463, 10471

# %% [markdown]
# Zip codes are there as CSVs. Convert them to a list

# %%
df.Zips = df.Zips.str.split(',')

# %%
df.head()
# Out:
#   Borough                Neighborhood                             Zips
# 1   Bronx               Central Bronx          [10453,  10457,  10460]
# 2   Bronx      Bronx Park and Fordham          [10458,  10467,  10468]
# 3   Bronx  High Bridge and Morrisania          [10451,  10452,  10456]
# 4   Bronx  Hunts Point and Mott Haven  [10454,  10455,  10459,  10474]
# 5   Bronx   Kingsbridge and Riverdale                  [10463,  10471]

# %% [markdown]
# Manipulate data to get it in the format: Borough, Neighborhood, ZipCode

# %%
tempZipDF = pd.concat([pd.DataFrame({'ZipCode':v}, index=np.repeat(k,len(v))) 
            for k,v in df.Zips.to_dict().items()])   
tempZipDF

neighborhoodsDF = df

neighborhoodMappingsDF = (
    neighborhoodsDF.merge(tempZipDF, left_index=True, right_index=True)
    .loc[:,['Borough', 'Neighborhood', 'ZipCode']]
)

neighborhoodMappingsDF.head()
# Out:
#   Borough            Neighborhood ZipCode
# 1   Bronx           Central Bronx   10453
# 1   Bronx           Central Bronx   10457
# 1   Bronx           Central Bronx   10460
# 2   Bronx  Bronx Park and Fordham   10458
# 2   Bronx  Bronx Park and Fordham   10467

# %%
neighborhoodMappingsDF.to_pickle('neighborhoodMapp')
# Out:
#           Borough                Neighborhood ZipCode
# 1           Bronx               Central Bronx   10453
# 1           Bronx               Central Bronx   10457
# 1           Bronx               Central Bronx   10460
# 2           Bronx      Bronx Park and Fordham   10458
# 2           Bronx      Bronx Park and Fordham   10467
# 2           Bronx      Bronx Park and Fordham   10468
# 3           Bronx  High Bridge and Morrisania   10451
# 3           Bronx  High Bridge and Morrisania   10452
# 3           Bronx  High Bridge and Morrisania   10456
# 4           Bronx  Hunts Point and Mott Haven   10454
# 4           Bronx  Hunts Point and Mott Haven   10455
# 4           Bronx  Hunts Point and Mott Haven   10459
# 4           Bronx  Hunts Point and Mott Haven   10474
# 5           Bronx   Kingsbridge and Riverdale   10463
# 5           Bronx   Kingsbridge and Riverdale   10471
# 6           Bronx             Northeast Bronx   10466
# 6           Bronx             Northeast Bronx   10469
# 6           Bronx             Northeast Bronx   10470
# 6           Bronx             Northeast Bronx   10475
# 7           Bronx             Southeast Bronx   10461
# 7           Bronx             Southeast Bronx   10462
# 7           Bronx             Southeast Bronx   10464
# 7           Bronx             Southeast Bronx   10465
# 7           Bronx             Southeast Bronx   10472
# 7           Bronx             Southeast Bronx   10473
# 8        Brooklyn            Central Brooklyn   11212
# 8        Brooklyn            Central Brooklyn   11213
# 8        Brooklyn            Central Brooklyn   11216
# 8        Brooklyn            Central Brooklyn   11233
# 8        Brooklyn            Central Brooklyn   11238
# ..            ...                         ...     ...
# 36         Queens            Southeast Queens   11427
# 36         Queens            Southeast Queens   11428
# 36         Queens            Southeast Queens   11429
# 37         Queens            Southwest Queens   11414
# 37         Queens            Southwest Queens   11415
# 37         Queens            Southwest Queens   11416
# 37         Queens            Southwest Queens   11417
# 37         Queens            Southwest Queens   11418
# 37         Queens            Southwest Queens   11419
# 37         Queens            Southwest Queens   11420
# 37         Queens            Southwest Queens   11421
# 38         Queens                 West Queens   11368
# 38         Queens                 West Queens   11369
# 38         Queens                 West Queens   11370
# 38         Queens                 West Queens   11372
# 38         Queens                 West Queens   11373
# 38         Queens                 West Queens   11377
# 38         Queens                 West Queens   11378
# 39  Staten Island               Port Richmond   10302
# 39  Staten Island               Port Richmond   10303
# 39  Staten Island               Port Richmond   10310
# 40  Staten Island                 South Shore   10306
# 40  Staten Island                 South Shore   10307
# 40  Staten Island                 South Shore   10308
# 40  Staten Island                 South Shore   10309
# 40  Staten Island                 South Shore   10312
# 41  Staten Island    Stapleton and St. George   10301
# 41  Staten Island    Stapleton and St. George   10304
# 41  Staten Island    Stapleton and St. George   10305
# 42  Staten Island                  Mid-Island   10314
#
# [178 rows x 3 columns]
